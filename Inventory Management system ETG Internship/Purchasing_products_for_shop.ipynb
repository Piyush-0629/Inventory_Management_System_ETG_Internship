# %% [markdown]
# #Read data from **JSON**

# %%
import json
fd = open("products.json",'r')
r = fd.read()
fd.close()

products = json.loads(r)

# %%
products
# Out:
# {'1001': {'brand': 'Pepsi',
#   'expiry': '20 oct 2023',
#   'name': 'Pepsi Can',
#   'price': 153,
#   'quan': 50},
#  '1002': {'brand': 'Tata',
#   'expiry': '12 jan 2022',
#   'name': 'Tata Salt',
#   'price': 20,
#   'quan': 130},
#  '1003': {'brand': 'Tata',
#   'expiry': '10 mar 2023',
#   'name': 'Tata Tea ',
#   'price': 48,
#   'quan': 145},
#  '1004': {'brand': 'Tata',
#   'expiry': '23 jun 2023',
#   'name': 'Turmeric Powder',
#   'price': 52,
#   'quan': 122},
#  '1005': {'brand': 'Quaker',
#   'expiry': '30 oct 2022',
#   'name': 'Quaker Oats',
#   'price': 285,
#   'quan': 30},
#  '1006': {'brand': 'Saffola',
#   'expiry': '29 jan 2022',
#   'name': 'Saffola Active',
#   'price': 207,
#   'quan': 58},
#  '1007': {'brand': 'Nestle',
#   'expiry': '31 aug 2022',
#   'name': 'Kitkat Desert',
#   'price': 55,
#   'quan': 59},
#  '1008': {'brand': 'Dark Fantasy',
#   'expiry': '21 feb 2022',
#   'name': 'Dark Fantasy ',
#   'price': 90,
#   'quan': 90},
#  '1009': {'brand': 'Candyman Fantastik',
#   'expiry': '28 dec 2021',
#   'name': 'Candyman Fantasy',
#   'price': 80,
#   'quan': 95},
#  '1010': {'brand': 'Lotte',
#   'expiry': '01 jun 2022',
#   'name': 'Lotte Choco Pie',
#   'price': 110,
#   'quan': 95},
#  '1011': {'brand': 'Britania',
#   'expiry': '15 jul 2022',
#   'name': 'Britania  cake',
#   'price': 120,
#   'quan': 100},
#  '1012': {'brand': 'Pillsbury',
#   'expiry': '02 dec 2021',
#   'name': 'Pillsbury cake',
#   'price': 90,
#   'quan': 200},
#  '1013': {'brand': 'Ore0',
#   'expiry': '30 dec 2021',
#   'name': 'Oreo Soft Cake',
#   'price': 249,
#   'quan': 120},
#  '1014': {'brand': 'Sunfeast',
#   'expiry': '19 mar 2022',
#   'name': 'Magic Cashew',
#   'price': 80,
#   'quan': 180},
#  '1015': {'brand': 'Cadbury',
#   'expiry': '19 feb 2022',
#   'name': 'Oreo chacolate',
#   'price': 60,
#   'quan': 185},
#  '1016': {'brand': 'Betty Croker',
#   'expiry': '15 jan 2022',
#   'name': 'Betty  Pancake',
#   'price': 346,
#   'quan': 190},
#  '1017': {'brand': 'Parle',
#   'expiry': '13 dec 2011',
#   'name': 'Parle Original',
#   'price': 67,
#   'quan': 140},
#  '1018': {'brand': "Lay's",
#   'expiry': '14 feb 2023',
#   'name': 'Potato Chips',
#   'price': 30,
#   'quan': 450},
#  '1019': {'brand': 'Bingo!',
#   'expiry': '20 dec 2023',
#   'name': 'Bingo! Mad Angle',
#   'price': 25,
#   'quan': 440},
#  '1020': {'brand': "Kellog's",
#   'expiry': '25 jan 2024',
#   'name': 'Pringles',
#   'price': 85,
#   'quan': 400},
#  '1021': {'brand': "Dorito's",
#   'expiry': '22 jan 2023',
#   'name': "Dorito's  Chips",
#   'price': 90,
#   'quan': 360},
#  '1022': {'brand': 'Thums Up',
#   'expiry': '20 dec 2024',
#   'name': 'Soft Drink',
#   'price': 40,
#   'quan': 60},
#  '1023': {'brand': 'Svami',
#   'expiry': '20 jun 2023',
#   'name': 'Soda Water',
#   'price': 55,
#   'quan': 70},
#  '1024': {'brand': 'Coca Cola',
#   'expiry': '22 jul 2023',
#   'name': 'Coca-Cola',
#   'price': 65,
#   'quan': 60},
#  '1025': {'brand': 'Sprite',
#   'expiry': '20 nov 2023',
#   'name': 'Sprite Lime ',
#   'price': 89,
#   'quan': 40},
#  '1026': {'brand': 'Colgate',
#   'expiry': '20 jun 2024',
#   'name': 'Colgate Maxfresh',
#   'price': 215,
#   'quan': 55},
#  '1027': {'brand': 'Pepsodent',
#   'expiry': '15 jul 2022',
#   'name': 'Pepsodent ',
#   'price': 300,
#   'quan': 150},
#  '1028': {'brand': 'DABUR',
#   'expiry': '10 aug 2024',
#   'name': 'Dabur Amla Oil',
#   'price': 247,
#   'quan': 100},
#  '1029': {'brand': 'Nivea',
#   'expiry': '31 jul 2022',
#   'name': 'Men Face Wash',
#   'price': 149,
#   'quan': 98},
#  '1030': {'brand': 'Himalaya',
#   'expiry': '22 may 2022',
#   'name': 'Himalaya cream',
#   'price': 104,
#   'quan': 200}}

# %% [markdown]
# #Purchasing new items for Inventory

# %%
prod_id = input("Enter the Product ID: ")
name = input("Enter the Name of the Product: ")
price = int(input("Enter the price per Item: "))
quan = int(input("Enter The Quantity of the Product you want to add: "))
expiry = input("Enter the expiry date of the Product: ")
brand = input("Enter the Brand of the product: ")

products[prod_id] = {"name":name,"price":price,"quan":quan,"expiry":expiry,"brand":brand}

js = json.dumps(products)

fd = open("products.json","w")
fd.write(js)
fd.close()
# Out:
# Enter the Product ID: 1031
# Enter the Name of the Product: Bathing soap
# Enter the price per Item: 35
# Enter The Quantity of the Product you want to add: 426
# Enter the expiry date of the Product: 24 nov 2034
# Enter the Brand of the product: Nivea

# %%
products
# Out:
# {'1001': {'brand': 'Pepsi',
#   'expiry': '20 oct 2023',
#   'name': 'Pepsi Can',
#   'price': 153,
#   'quan': 50},
#  '1002': {'brand': 'Tata',
#   'expiry': '12 jan 2022',
#   'name': 'Tata Salt',
#   'price': 20,
#   'quan': 130},
#  '1003': {'brand': 'Tata',
#   'expiry': '10 mar 2023',
#   'name': 'Tata Tea ',
#   'price': 48,
#   'quan': 145},
#  '1004': {'brand': 'Tata',
#   'expiry': '23 jun 2023',
#   'name': 'Turmeric Powder',
#   'price': 52,
#   'quan': 122},
#  '1005': {'brand': 'Quaker',
#   'expiry': '30 oct 2022',
#   'name': 'Quaker Oats',
#   'price': 285,
#   'quan': 30},
#  '1006': {'brand': 'Saffola',
#   'expiry': '29 jan 2022',
#   'name': 'Saffola Active',
#   'price': 207,
#   'quan': 58},
#  '1007': {'brand': 'Nestle',
#   'expiry': '31 aug 2022',
#   'name': 'Kitkat Desert',
#   'price': 55,
#   'quan': 59},
#  '1008': {'brand': 'Dark Fantasy',
#   'expiry': '21 feb 2022',
#   'name': 'Dark Fantasy ',
#   'price': 90,
#   'quan': 90},
#  '1009': {'brand': 'Candyman Fantastik',
#   'expiry': '28 dec 2021',
#   'name': 'Candyman Fantasy',
#   'price': 80,
#   'quan': 95},
#  '1010': {'brand': 'Lotte',
#   'expiry': '01 jun 2022',
#   'name': 'Lotte Choco Pie',
#   'price': 110,
#   'quan': 95},
#  '1011': {'brand': 'Britania',
#   'expiry': '15 jul 2022',
#   'name': 'Britania  cake',
#   'price': 120,
#   'quan': 100},
#  '1012': {'brand': 'Pillsbury',
#   'expiry': '02 dec 2021',
#   'name': 'Pillsbury cake',
#   'price': 90,
#   'quan': 200},
#  '1013': {'brand': 'Ore0',
#   'expiry': '30 dec 2021',
#   'name': 'Oreo Soft Cake',
#   'price': 249,
#   'quan': 120},
#  '1014': {'brand': 'Sunfeast',
#   'expiry': '19 mar 2022',
#   'name': 'Magic Cashew',
#   'price': 80,
#   'quan': 180},
#  '1015': {'brand': 'Cadbury',
#   'expiry': '19 feb 2022',
#   'name': 'Oreo chacolate',
#   'price': 60,
#   'quan': 185},
#  '1016': {'brand': 'Betty Croker',
#   'expiry': '15 jan 2022',
#   'name': 'Betty  Pancake',
#   'price': 346,
#   'quan': 190},
#  '1017': {'brand': 'Parle',
#   'expiry': '13 dec 2011',
#   'name': 'Parle Original',
#   'price': 67,
#   'quan': 140},
#  '1018': {'brand': "Lay's",
#   'expiry': '14 feb 2023',
#   'name': 'Potato Chips',
#   'price': 30,
#   'quan': 450},
#  '1019': {'brand': 'Bingo!',
#   'expiry': '20 dec 2023',
#   'name': 'Bingo! Mad Angle',
#   'price': 25,
#   'quan': 440},
#  '1020': {'brand': "Kellog's",
#   'expiry': '25 jan 2024',
#   'name': 'Pringles',
#   'price': 85,
#   'quan': 400},
#  '1021': {'brand': "Dorito's",
#   'expiry': '22 jan 2023',
#   'name': "Dorito's  Chips",
#   'price': 90,
#   'quan': 360},
#  '1022': {'brand': 'Thums Up',
#   'expiry': '20 dec 2024',
#   'name': 'Soft Drink',
#   'price': 40,
#   'quan': 60},
#  '1023': {'brand': 'Svami',
#   'expiry': '20 jun 2023',
#   'name': 'Soda Water',
#   'price': 55,
#   'quan': 70},
#  '1024': {'brand': 'Coca Cola',
#   'expiry': '22 jul 2023',
#   'name': 'Coca-Cola',
#   'price': 65,
#   'quan': 60},
#  '1025': {'brand': 'Sprite',
#   'expiry': '20 nov 2023',
#   'name': 'Sprite Lime ',
#   'price': 89,
#   'quan': 40},
#  '1026': {'brand': 'Colgate',
#   'expiry': '20 jun 2024',
#   'name': 'Colgate Maxfresh',
#   'price': 215,
#   'quan': 55},
#  '1027': {'brand': 'Pepsodent',
#   'expiry': '15 jul 2022',
#   'name': 'Pepsodent ',
#   'price': 300,
#   'quan': 150},
#  '1028': {'brand': 'DABUR',
#   'expiry': '10 aug 2024',
#   'name': 'Dabur Amla Oil',
#   'price': 247,
#   'quan': 100},
#  '1029': {'brand': 'Nivea',
#   'expiry': '31 jul 2022',
#   'name': 'Men Face Wash',
#   'price': 149,
#   'quan': 98},
#  '1030': {'brand': 'Himalaya',
#   'expiry': '22 may 2022',
#   'name': 'Himalaya cream',
#   'price': 104,
#   'quan': 200},
#  '1031': {'brand': 'Nivea',
#   'expiry': '24 nov 2034',
#   'name': 'Bathing soap',
#   'price': 35,
#   'quan': 426}}
